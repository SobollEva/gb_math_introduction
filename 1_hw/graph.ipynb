# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-10, 10, 50)
k_1 = 1
k_2 = 1.6
plt.plot(x, np.cos(k_1*x), marker="o")
plt.plot(x, np.cos(k_2*x), marker="*")
